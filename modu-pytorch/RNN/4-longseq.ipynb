# %% [markdown]
# 긴 문장으로 부터 다음 문장을 예측하는 모델을 만들어보자.</br>
# 긴 문장을 특정 사이즈로 잘라서 훈련한다.</br>

# %%
import torch
import torch.optim as optim
import numpy as np

# Random seed to make results deterministic and reproducible
torch.manual_seed(0)

sentence = ("if you want to build a ship, don't drum up people together to "
            "collect wood and don't assign them tasks and work, but rather "
            "teach them to long for the endless immensity of the sea.")

# make dictionary
char_set = list(set(sentence))
# character 사전을 만든다. index -> char
char_dic = {c: i for i, c in enumerate(char_set)}

# hyper parameters
dic_size = len(char_dic)
hidden_size = len(char_dic)
# 긴 문장을 자를 크기를 설정한다.
sequence_length = 10
learning_rate = 0.1

# data setting
x_data = []
y_data = []

# 가져올 수 있는 청크의 개수만큼 루프를 돈다.
chunk_count = len(sentence) - sequence_length
for i in range(0, chunk_count):
    x_str = sentence[i:i + sequence_length]             # 예를들어 "if you wan"가 입력이면
    y_str = sentence[i + 1: i + sequence_length + 1]    # 예를들어 "f you want"가 정답이 된다.
    # print(i, x_str, '->', y_str)
    
    x_data.append([char_dic[c] for c in x_str])  # x str to index
    y_data.append([char_dic[c] for c in y_str])  # y str to index

# np.eye 함수를 사용해서 원-핫 벡터로 만든다. 
x_one_hot = [np.eye(dic_size)[x] for x in x_data]

# transform as torch tensor variable
X = torch.FloatTensor(x_one_hot)
Y = torch.LongTensor(y_data)


# 좀 더 크고 복잡한 모델을 만들기 위해서 RNN을 스택으로 쌓고 Fully Connected로 연결한다.
class Net(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, layers):
        super(Net, self).__init__()
        self.rnn = torch.nn.RNN(input_dim, hidden_dim, num_layers=layers, batch_first=True)
        self.fc = torch.nn.Linear(hidden_dim, hidden_dim, bias=True)

    def forward(self, x):
        x, _status = self.rnn(x)
        x = self.fc(x)
        return x


net = Net(
    dic_size, 
    hidden_size,
    2   # layer를 2로 설정해서 RRN을 2 스택으로 한다.
)

# loss & optimizer setting
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), learning_rate)

# start training
for i in range(100):
    optimizer.zero_grad()   # gradient를 초기화한다.
    outputs = net(X)        # 모델에 입력을 넣는다.
    # 모델의 output과 label을 비교해서 loss를 구한다.
    loss = criterion(outputs.view(-1, dic_size), Y.view(-1))
    loss.backward()
    optimizer.step()    # optimizer에 넣었던 네트워크의 파라미터를 업데이트한다.

    # 3번째 차원의 값들중 가장 큰 값의 인덱스를 가져온다. 
    results = outputs.argmax(dim=2)
    predict_str = ""
    for j, result in enumerate(results):
        # print(i, j, ''.join([char_set[t] for t in result]), loss.item())
        if j == 0:
            predict_str += ''.join([char_set[t] for t in result])
        else:
            predict_str += char_set[result[-1]]     # 맨 마지막 결과를 가져온다.

    print(predict_str)
# Out:
# b'wtt wttwt'wwwwt ''wt'w'w'twwtw'''wtww'wt'ttwttt'w'tww'ttww'wwtwtt'''wtww'twt''tw'''w'w 'wwt'wt'w''w'wwwe'ttwwt'wtw'ttw'wwwwwwb''w'ww'wtwwtwt''ttww'wwww''t''wwtttt' ''wt'ww'ww'ww
#
# totootoottottotoottottoottotttotttttottotttttotottootooototottootoottottottottttotoottottottoottttotottootttottottootoottottoooootoottotttoottottootttoottotttttototottootootottott
#  kb l.e k..e...''..'h.'e.......'...h.e..h....e.e...n..he.''...h...n..eh.h..h..h....h...e.ee..h..........ee.....e..hh..e..e'...e....e'.....'...eh.'e....h..e'....'......e.........h.
# aalua la llalllullllallaulullulallullalllllllallallaallallallllllluallalllllllallllulllallullullllllullllalllllllllallulllalllallllaalllllullllallullllallualllllllllllllllllllllal
# e le ha haaenaaeneanelaaenataaae aeaaeneanlaaenaeaaaeaa leelana naatne ne aalnenaeaaeaaenaanneennaneen aaenaae aaaatnaeaneealeea naetneanean aetneeneentnaaennaaaeaeenneeaaea enaae
#   n r                                                                                                                  h
#
#    la l     l    t                l    l l   l t   tll        l  l      l  l        l         l    l   tl       l     l   ll llt   l  tt l   tl   l       t   t t l t  ll ll
#    t  t   het h  t  e  ee e h heh t    l e   t t hetttht l  h t eth  h  l  t    hhh t he lee ethh  t   th   h h t  e  t   tt ett  ll  tt    elh   t h    ht   tetel t htttlt    h h
#    t  t et tt to t  t   t e u  t  t    ttt   t tt tttt t t    t tt      t  t     t tt  t ttt tt    t   t t    utt  t  t  ttt ttt  t   tt t   t t  t  t t  t   ttttt t  ttt t  t h t
#  o t  t et tt  o tt t  tt to t t ttt t  t  t t tt tttt tott  et tt t  t tott  t    ttt t ttt tt  tett tt t   o ttt t ettettt tttett t  t tt tt t  t  t t   t ttttttot  ttt to t  t
#  o tr t et t   o tt t etteto t t  ttet  t  t t tt tttt tott  et tt t  o tottt t    ttt t tt  tt  tett tt t   o ttoet etoet t ttt tt t tt tt tt t  tr t te  t ttttttot  ttt to t  t
#  o tn t ee tt to to to  t tt o t  tt t tt  e t tt o tt et to eo tt t to ttttt t  ttttr t ttt tt  o tt tt t   o tto t ett tttoet  to t tt te to e  t  t t  tt ttttotot  ttt to t  t
# ao tn th t t   o  e th tt to t t  to t  t  t    t a a  tt th    te t  ot tntt t     te t  t      o tt te t   e   e tt  o t tht t to t tto o te tt th t a   t  t tt ot   t  to t  t
# gotontt to t n o to t tate   o a  toe  tmetettt a on n e  to th ao  o oe ht   t    oto teo  o    o te teaae  o  to o   oeo toato to o ta  o aotoetth      oo tto otnt   t tthe t o
# g tot   aootoo oto  tot aat ton   o nm t n o atoo onotoo om  th a aooto a  m  t oatot nmna t tm ohem  tdn o n otto onnt nm   eaonthtm to  o o to  thateoo ot mtomo  t  ntogohnm omo
# g toe t eo tog o od t tme t toge  t om togte asoothgetoe oth th ed t to l  e  tonetod  egedt ot  o mo tdgo  noloto og tontod etooto t to  o o  o  t et eo et  to  e t   toethgt ott
# g to l  en oogtoten o t e e  o et t  m to  eth  oto eton ot   ogln o to on e  togltoe  m onl lm  oteo tegotheeottotototo tothepo  ote eo lo onto  t eetet ot  oo  o tlh eotpo etonl
# g to  t ' otoelot   t tmnln loo,pht tt to  ote l th e on othll  ln t to l tos to l oe tt   t em toe oltol tooom tot tothlmetonmoothet oo lo e to lm eo mt e  loe  o d o to t  m  nl
# g to  the tto lot t t   nltoto t ht  t to tot t  to e  e eth  o ld totoe o 's th gthe  e  tth t to  o t,   o et to  ehtott'them  to m to lo en oe thet et et lto  e t h te to tt nl
# b to  the   o  otot t   e t  o ' heo m t  te  e   o ' he oth  o ed t to g  'e t  e hto e  dth m  o  o  '  th e  tot thto mhthebh  o kseh  o  n o  toe   e et  th  e meh e   h  she
# g tor the  to l tot t t s t  on'  thum t gte  e  to n he  th lo ed toto l  ns t  etheotns dth m totso tne to  ' tot teth m theb nto m to lo n  o ethett e em  tu  e meh t  th mtus
# b tonttoe  togtotes tot tbt tognt toet t gtn  e  to n  e etoeto ed toto l tn  to l he   s dto m tosso wsg toe l tot tnth m tonb nwoem tonto n to  the  oe nm  t  oes  h tn themtus
# m to  toer togtotes tot t t tonntht em t  tu es mto n  e oto toeed t to e tns tonl her  i dthem to mt tug toe n tutotothemethsm  w em tonto n to  the tnd e   t   es  h tn the tost
# mtto  toer tontoted tntnt t to ntht  m th tu nsetto nt e  th  h ed t to l tns tonlt dr    tthem to  t tog toe d tutotothet thnm nwhe  tonto l to  the tud et  tn  ndt   an toe t
# mttonwtoed to tut d tnt tmt to l  do t tm tn id ltonet erato to  d a to  ttln t  dthdd t  dthet to mt io  thnn  tutat them thec  toem tonto ne on toedte  nm  tn odd    tn toemtnr
# m tonttoed to tn  d tnt mpt to l  do t tmetn  d ttond he  to to gd a to  ttld th d hdr tm dthe  to mt io  thn   tui t them the t toec  o po g  o  toe te  nmi tn  ld d  lo toemt dt
# m tonw oed to tnt d aftnmgt to 'thd et dmutn  a atod' he  toeto gt   to e t'd aoa'thd      toe  to mt tnr ton   tnt tethe  theih toem to to g ta  the ted emtstn  e pd  eo themt dt
# m tonttoedhth tnt d aft tpt to 'thdo t t tte  e  toae  e  toeto ed a to   t'd ao 't dr t   toe  to id tnd toen  tnt tgthep todi  toep to teng to  the tea emi to hddi  aer toemt tc
# k too toed do tnt d totnsp, toa't doet t  te  e  thgnt e  thethuedpt tor' tnd doe'thdfci   them to sd tnd togns tnt dot    toect toec tortend ton toested emc tl  nsip  eo toemt ap
# g too t ed toebnt d tnt sp, toa't doem t  to  e  thans e ethgtou'd t tor' tnd do 't dfci   them to sd tnd tones tnt dot e  t ectetoek to bend tor'the tod esc tl ensit uaf toemt a
# g too t nd to bui d t t sp, toadt d em t  ton e  thans e  thntould thto l tnd doa't dsci   them to ps tus tonne tui d the  thettetoen to bond torlt e tod esc tl  nspthalf themt a
# g too t ndhdo bui d t t ,p, to lt d um t  ton ee thans em thntould t torl tod do lt dss m  them to mt tndhtonne tuihd the  th ct them to bonl to  t e tod ess tl  nsmt  or thest l
# g toucwundhdo build tst ip, tonlt d um tp to  ee tonnt em thntonld t tool tnd to lt dssi  mthem to mt tndhton e tui d the  to ctethem tonbenl torlthe tnd ess tl  nsmdy oo toemw l
# m too tundhao build tft ip, tonlt drum tp pon ,e thnnt ei tonto le t torl tnd to lt dssig rthem tormt iud ton e tui d the  th c ethem tonbonl tonltoe tnd esp tl  nsidy or toemwnlp
# m toa tundhtonbuild tnt ip, to lt d um tp pen eesthnnshet thntonle t torl tnd tonlt dssigumthem tor i tnd ton s tui dgthe  to c ethem tonbunl tonlthe tnd nni tl  nsidy or themtntp
# m tooctund tonbuild tst ip, tonlt drum tp te pee thnethei t ntonle t torl tnd to lt dssimu'them to is ind to lt tui d them tonc  toem torbund tonmthemtnd ensitl  nsidy es toemt ts
# m touctunt tonbuild t t ip, ton't d um tp pe pee thaethe  thatonlt t tor' tns ton't dssigumthem torct tnd ton t tut de he  to c  toem torbond sonlthe tnd essitl  nsidy er themt e
# m tou tund torbuild ant ip, ton't erum ap penpee to ethe  thgcouee t tork tnd to 't dssig mthem torct tnd ton e tut eu he  to cietoem worcon' sonlthe soe e c tl  ntith eo themt es
# g tou wund tonbuild tnt ep, aon't drum ap penpee to ethe  to couee t aood tpd aon't dssig mthem toeps tod aourd tut dethe  to ca toem toncon' sonlthe toe ess t'  nspdh oo toemt dc
# g tou tund wo build ast ip, to 't drum ap penpee to ethe  to sou'e t wood tns to 't dssigk them whspi tnd to  s tut dothep to chethem to bon' sorlt e sn' ess t' ensidy os themt ds
# p tou wundhworbuild ant tp, do 't aoum ap penple to ethe  th so 'e t wood tns to 't assig  them dosss tns wor , aui rethep to ch them to cond sorlt e and e sit' ensity of themtod
# p aoo tund wo buipd tnt sp, don't doum wp penpl  to ethe  to son'e t wood tnd to 't dssig mthem to ssitnd wo l, tut oothep to shetoem to bong sonlthe snd ess tm  nsity of themt d
# p poo tunt to bui d bnt sm, do 't doum ap penple to ethe  th ton'e t wood tnd to 't dssign t em to ks tnd to  , but dothep to sh them to long sonlt e snd e s tm ensity of themt d
# p aoo wunt to bui d tnthip, do 't doum up penple to ethe  to tonle t uool wnd to 't dss em them to ps tnd tor , tut rothep to sh them wo long sonlt e and ess tm ensily of thems ds
# l aoo wunt to bui d t thip, do 't drum ap penple to ethe  to donle t uord und do 't dssigm them to ps tnd tor , bui dathep to ch them to lond sonlthemsnd ess tm ensidy of thems d
# g aoo wunt to bui d a thip, do 't doum ap penple togethe  to dogee t tood tnd don't dssign them to ki tnd tor , bui rethep to ch them to long sonlthemsnd ess tm ensity of thems ds
# g aou wunt ao build asship, dog't drum tp people together to dogee t wood wnd don't dssign them to cs tnd tor , bui dathep to ctethem to long sorlthe  nd ess im ensity of themands
# g aou want to luild a ship, dog't drum tp penple together togtogeect wor' tnd don't dssign them tosks t d tor , aui dathep to ch them to long sorlthe snd ess im ensity of thema d
# g aou want to build a ship, do 't arum up penple together togcogeect word wnd do 't assign them tosks tnd wor , aui dathep to ch them to long sorlthe snd ess im ensity of thema d
# r aou want to build a ship, do 't arum up penple together to tonle t tord wnd won't assign them tosks tnd wor , bui dathe  to ch toem to bong sorlthemsnd ess im ensity of the s ds
# p aor want th butld a fhip, don't drum tp penple torether torcoulect tord wnd won't assign them thsks tnd wor , aut rathe  to ch them to long torlthemsnd ess im ensity of thems ts
# p aou want to build a ship, don't drum tp penple together togcollect tord und won't dssign them thsks tnd wor , but rathe  ta ch them to long forlthemsnd ess im ensipy of the s ts
# p pou want ao butld a s ip, do 't drum tp people togethe  togtonlect tord wnd tongt dssign them tosk, tnd uor , but dathe  th ct toem to bong torlthe snd ess tg ensipy of the snds
# m wou want to luild asship, ao 't arum up people togetherltogcoulect tord wnd won't assign them thsksstnd aor , bui ruthep to ch them to long forlt e sod ess il ensipy of the s bs
# m poutwant to build a ship, do 't drum up people together togpoulect tord wnd don't dssign them tosks tnd wor , bui rathe  to ch them to long forltae sod ess igmensi,y of the a as
# m pou want to build a fhip, don't drum up people together togcoulect tord wnd don't dssign them tosks tnd work, but rathe  to ch ther to long fonlthe snd ess immensity of the s ts
# m pou want to build a ship, don't drum up people together togcoulect tord tnd do 't dssign them tasks and work, but rathep to ch them to long fonlthe snd ess immensity of the s as
# l pou want th build a thip, don't drum up people together togpoulect tord wnd don't dsssgncthem tasks and work, but rathe  toach ther to bong for the end ess immensity of the a as
# l poutwant to build d fhip, don't drum up people together togpoulect tord wnd don't dssigncthem thsks and dork, but rather toach them to bong for the ehd ess tmmensity of the a as
# l por want th build a thip, don't arum up people together togcollect tord wnd do 't assigncthe  tosks and dork, but rathep te ct them to long torlthe snd ess immensity of the   a
# l poo want th build a t ip, don't drum up people toget er togcollect tood and wo 't dssign the  tosks and dork, but rathe  tesct them to long forlthe snd ess immensity of the a ts
# l aou want to build a f ip, don't drum up people toget er togpollect uood and wo 't dssign them tosks and work, but rather toach toem to long for the end ess immensity of the a as
# l aou want to build a fhip, don't arum up people together toapollect tood and won't assign them tosks and work, but rather toach toem to long for the en'less immensity of the s fs
# l aou want to luild a ship, don't arum up people together toacollect tord wnd won't assign them tasks and work, but rather toach ther to long for the endless immensity of the snas
# l pou want to luild a ship, don't drum up people together toacollect tord wnd wo 't dssign them tasks and work, bui rather toach ther to long for the endless immensity of the anb
# p pou want to build a ship, don't arum up people together toacollect tord wnd wo 't assign them tasks and work, bui rather toach them to long for the endless immensity of the a a
# p aou want th build a ship, don't arum up people together toacollect tord wnd won't assign them tasks and work, but rather toach them to long for the endless immensity of thems ai
# l aou want to build a ship, don't drum up people together toacollect tord wnd don't dssign them tasks and work, but rather toach them to long for the endless immensity of the s ai
# l pou want to build a ship, don't drum up people together toacollect tood wnd don't dssign them tasks and work, but rather toach them to long for the endless immensity of the s ti
# l pou want to build a ship, don't arum up people together to collect wood wnd don't assign them tasks and work, but rather teach them to long for the endless immensity of the snai
# l pou want to build a ship, don't arum up people together to collect wood wnd won't assign them tasks and work, but rather teach them to long for the endless immensity of the anai
# l pou want to luild a ship, don't arum up people together to collect wood wnd won't assign them tasks and work, but rather teach them to long for the endless immensity of the enai
# l pou want to luild a ship, don't arum up people together to collect wood wnd won't assign them tasks and work, but rather teach them to long for the sndless immensity of the snai
# l pou want to build a ship, don't drum up people together to collect wood wnd don't dssign them tasks and work, but rather teach them to long for the endless immensity of the a ai
# l aou want to build a ship, don't drum up people together to collect wood wnd don't assign them tasks and work, but rather teach them to long for the endless immensity of the a ai
# l pou want to build a ship, don't arum up people together to collect wood wnd don't assign them tasks and work, but rather teach them to long for the endless immensity of the s ai
# l pou want to build a ship, don't arum up people together to collect wood wnd don't assign them tasks and work, but rather teach them to long for the endless immensity of the snai
# l pou want to build a ship, don't drum up people together to collect wood wnd don't dssign them tasks and work, but rather teach them to long for the endless immensity of the snai
# l pou want to build a ship, don't drum up people together to collect wood wnd don't dssign them tasks and work, but rather teach them to long for the endless immensity of the srai
# l pou want to build a ship, don't drum up people together to collect wood wnd don't dssign them tasks and work, but rather teach them to long for the endless immensity of the aeai
# l pou want to build a ship, don't drum up people together to collect wood wnd don't dssign them tasks and work, but rather teach them to long for the endless immensity of the seai
# l oou want to build a ship, don't drum up people together to collect wood wnd don't assign them tasks and work, but rather teach them to long for the endless immensity of the seai
# l oou want to build a ship, don't drum up people together to collect wood wnd don't dssign them tasks and work, but rather teach them to long for the endless immensity of the seai
# l oou want to build a ship, don't drum up people together to collect wood wnd don't dssign them tasks and work, but rather teach them to long for the endless immensity of the seai
# l oou want to build a ship, don't drum up people together to collect wood wnd don't assign them tasks and work, but rather teach them to long for the endless immensity of the seai
# l oou want to build a ship, don't arum up people together to collect wood wnd don't assign them tasks and work, but rather teach them to long for the endless immensity of the seai
# g oou want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the seai
# l oou want to build a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them to long for the endless immensity of the seai
# l oou want to build a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them to long for the endless immensity of the seai
# r you want to build a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them to long for the endless immensity of the aeai
# r you want to build a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them to long for the endless immensity of the seai
# r you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the seai
# r you want to build a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them to long for the endless immensity of the eeai
# r you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the aeai
# r you want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the seai
# r you want to luild a ship, don't arum up people together to collect wood and don't assigncthem tasks and work, but rather teach them to long for the endless immensity of the eeai
# r you want to build a ship, don't arum up people together to collect wood and don't dssign them tasks and work, but rather teach them to long for the endless immensity of the seai
# g pou want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the srai
